# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # DATA CLEANING

# %%
img =cv2.imread('C:/Users/Dell/Desktop/MACHINE LEARNIG/DATA/lionel_messi/8e28dca199d2c529e710f2fc7550fc85.jpg')
img
# Out:
# array([[[229, 221, 221],
#         [229, 221, 221],
#         [229, 221, 221],
#         ...,
#         [225, 218, 215],
#         [225, 218, 215],
#         [225, 218, 215]],
#
#        [[229, 221, 221],
#         [229, 221, 221],
#         [229, 221, 221],
#         ...,
#         [225, 218, 215],
#         [225, 218, 215],
#         [225, 218, 215]],
#
#        [[229, 221, 221],
#         [229, 221, 221],
#         [229, 221, 221],
#         ...,
#         [225, 218, 215],
#         [225, 218, 215],
#         [225, 218, 215]],
#
#        ...,
#
#        [[213, 192, 194],
#         [216, 195, 197],
#         [216, 198, 199],
#         ...,
#         [196, 175, 178],
#         [198, 177, 180],
#         [200, 179, 182]],
#
#        [[212, 191, 193],
#         [215, 194, 196],
#         [216, 198, 199],
#         ...,
#         [197, 176, 179],
#         [200, 179, 182],
#         [202, 181, 184]],
#
#        [[207, 186, 188],
#         [211, 190, 192],
#         [213, 195, 196],
#         ...,
#         [195, 174, 177],
#         [197, 176, 179],
#         [198, 177, 180]]], dtype=uint8)

# %%
img.shape
# Out:
# (612, 408, 3)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 407.5, 611.5, -0.5)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (612, 408)

# %%
gray
# Out:
# array([[222, 222, 222, ..., 218, 218, 218],
#        [222, 222, 222, ..., 218, 218, 218],
#        [222, 222, 222, ..., 218, 218, 218],
#        ...,
#        [195, 198, 200, ..., 178, 180, 182],
#        [194, 197, 200, ..., 179, 182, 184],
#        [189, 193, 197, ..., 177, 179, 180]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('C:/Users/Dell/Desktop/MACHINE LEARNIG/haarcascades/haarcascade_frontalcatface_extended.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/Dell/Desktop/MACHINE LEARNIG/haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4508/4050794897.py in <module>
# ----> 1 face_cascade=cv2.CascadeClassifiers('C:/Users/Dell/Desktop/MACHINE LEARNIG/haarcascades/haarcascade_frontalcatface_extended.xml')
#       2 eye_cascade=cv2.CascadeClassifiers('C:/Users/Dell/Desktop/MACHINE LEARNIG/haarcascades/haarcascade_eye.xml')
#       3 faces=face_cascade.detectMultiScale(gray,1.3,5)
#       4 faces
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifiers'
